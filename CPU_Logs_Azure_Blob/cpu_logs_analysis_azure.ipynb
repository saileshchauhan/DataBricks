# %% [markdown]
# #### Author: Sailesh Chauhan
# #### Date: 25-07-2021
# #### Title: CPU_logs dataset has been analysed to find out solution for following problem statement.

# %% [markdown]
# 1. Finding users with lowest number of average hours using Data Bricks sql
# 2. Finding users with highest number of average hours using Data Bricks sql
# 3. Finding users with highest numbers of times late comings using Data Bricks sql
# 4. Finding users with highest numbers of idle hours using Data Bricks sql
# 5. Store the cleaning data on BLOB Storage
# 6. Store results on BLOB Storage

# %%
# %fs
ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_16.csv</td><td>CpuLogData2019_09_16.csv</td><td>177697</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_17.csv</td><td>CpuLogData2019_09_17.csv</td><td>299062</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_18.csv</td><td>CpuLogData2019_09_18.csv</td><td>286264</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_19.csv</td><td>CpuLogData2019_09_19.csv</td><td>346015</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_20.csv</td><td>CpuLogData2019_09_20.csv</td><td>136532</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_21.csv</td><td>CpuLogData2019_09_21.csv</td><td>291933</td></tr><tr><td>dbfs:/FileStore/tables/LMS_DB.zip</td><td>LMS_DB.zip</td><td>636912</td></tr></tbody></table></div>

# %%
# Mounting Azure Blob Storage
AZURE_KEY=spark.conf.get('spark.azure_key')
dbutils.fs.mount(
  source = "wasbs://cpulogsdata@cpulogs.blob.core.windows.net",
  mount_point = "/mnt/CPU_Logs_New",
  extra_configs ={"fs.azure.account.key.cpulogs.blob.core.windows.net":AZURE_KEY})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %%
# %fs
ls /mnt
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/CPU_Logs/</td><td>CPU_Logs/</td><td>0</td></tr><tr><td>dbfs:/mnt/CPU_Logs_New/</td><td>CPU_Logs_New/</td><td>0</td></tr></tbody></table></div>

# %%
# File location as list of file paths loading all files into data frame

file_location = ["/FileStore/tables/CpuLogData2019_09_16.csv","/FileStore/tables/CpuLogData2019_09_17.csv","/FileStore/tables/CpuLogData2019_09_18.csv","/FileStore/tables/CpuLogData2019_09_19.csv","/FileStore/tables/CpuLogData2019_09_20.csv","/FileStore/tables/CpuLogData2019_09_21.csv"]

file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

# Selecting only required columns from dataset.

df_CPU_logs=df.select("DateTime","user_name","keyboard","mouse")
rows=df_CPU_logs.count()
df_CPU_logs.describe()
rows
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 4122</div>

# %%
# Adding column time containing values in YYYY-MM-DD HH:mm from TimeStamp
from pyspark.sql.functions import date_format
df_CPU_logs_date_time = df_CPU_logs.withColumn('time', date_format('datetime', 'yyyy-MM-dd HH:mm'))


# Dropping date time columns
df_CPU_logs_date_time=df_CPU_logs_date_time.drop("DateTime")
df_CPU_logs_date_time.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------+------+----------------+
#            user_name|keyboard| mouse|            time|
# +--------------------+--------+------+----------------+
#   iamnzm@outlook.com|     1.0|  32.0|2019-09-19 08:40|
#   iamnzm@outlook.com|     0.0|   0.0|2019-09-19 08:45|
#   iamnzm@outlook.com|     0.0|   0.0|2019-09-19 08:50|
#   iamnzm@outlook.com|    11.0| 900.0|2019-09-19 08:55|
#   iamnzm@outlook.com|     2.0|  25.0|2019-09-19 09:00|
#   iamnzm@outlook.com|    37.0| 336.0|2019-09-19 09:05|
# deepshukla292@gma...|     0.0|  55.0|2019-09-19 09:05|
#   iamnzm@outlook.com|     0.0| 136.0|2019-09-19 09:10|
# deepshukla292@gma...|     6.0|1112.0|2019-09-19 09:10|
#   iamnzm@outlook.com|     0.0|  84.0|2019-09-19 09:15|
# deepshukla292@gma...|     0.0| 357.0|2019-09-19 09:15|
# markfernandes66@g...|    20.0| 670.0|2019-09-19 09:15|
# markfernandes66@g...|    17.0|   0.0|2019-09-19 09:10|
# markfernandes66@g...|    29.0|1895.0|2019-09-19 09:20|
#   iamnzm@outlook.com|     0.0|  29.0|2019-09-19 09:20|
# deepshukla292@gma...|    35.0|3022.0|2019-09-19 09:20|
# markfernandes66@g...|     2.0| 238.0|2019-09-19 09:25|
#   iamnzm@outlook.com|     0.0|   0.0|2019-09-19 09:25|
# deepshukla292@gma...|    20.0|1330.0|2019-09-19 09:25|
# markfernandes66@g...|     5.0|  39.0|2019-09-19 09:30|
# +--------------------+--------+------+----------------+
# only showing top 20 rows
#
# </div>

# %%
# Creating a parmanent table CpuLogData_All1

permanent_table_name = "CpuLogData_All1"

df_CPU_logs_date_time.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
--sql query to count total rows
SELECT COUNT(*) FROM CpuLogData_All1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>4122</td></tr></tbody></table></div>

# %%
# %sql
-- Analyze table and compute statistics.
ANALYZE TABLE CpuLogData_All1 COMPUTE STATISTICS;
DESC EXTENDED CpuLogData_All1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>user_name</td><td>string</td><td>null</td></tr><tr><td>keyboard</td><td>string</td><td>null</td></tr><tr><td>mouse</td><td>string</td><td>null</td></tr><tr><td>time</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>cpulogdata_all1</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Sun Jul 25 11:28:50 UTC 2021</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.1.0</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Provider</td><td>parquet</td><td></td></tr><tr><td>Statistics</td><td>45417 bytes, 4122 rows</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/cpulogdata_all1</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat</td><td></td></tr></tbody></table></div>

# %%
# %sql
-- 10 reocrds of table
SELECT  * FROM CpuLogData_All1 limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_name</th><th>keyboard</th><th>mouse</th><th>time</th></tr></thead><tbody><tr><td>iamnzm@outlook.com</td><td>1.0</td><td>32.0</td><td>2019-09-19 08:40</td></tr><tr><td>iamnzm@outlook.com</td><td>0.0</td><td>0.0</td><td>2019-09-19 08:45</td></tr><tr><td>iamnzm@outlook.com</td><td>0.0</td><td>0.0</td><td>2019-09-19 08:50</td></tr><tr><td>iamnzm@outlook.com</td><td>11.0</td><td>900.0</td><td>2019-09-19 08:55</td></tr><tr><td>iamnzm@outlook.com</td><td>2.0</td><td>25.0</td><td>2019-09-19 09:00</td></tr><tr><td>iamnzm@outlook.com</td><td>37.0</td><td>336.0</td><td>2019-09-19 09:05</td></tr><tr><td>deepshukla292@gmail.com</td><td>0.0</td><td>55.0</td><td>2019-09-19 09:05</td></tr><tr><td>iamnzm@outlook.com</td><td>0.0</td><td>136.0</td><td>2019-09-19 09:10</td></tr><tr><td>deepshukla292@gmail.com</td><td>6.0</td><td>1112.0</td><td>2019-09-19 09:10</td></tr><tr><td>iamnzm@outlook.com</td><td>0.0</td><td>84.0</td><td>2019-09-19 09:15</td></tr></tbody></table></div>

# %%
# Writing data to mounted Azure Blob Storage

df=spark.sql("""SELECT  * FROM CpuLogData_All1""")
df.write.csv('dbfs:/mnt/CPU_Logs/CpuLogData_All1')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------+------+----------------+
#            user_name|keyboard| mouse|            time|
# +--------------------+--------+------+----------------+
#   iamnzm@outlook.com|     1.0|  32.0|2019-09-19 08:40|
#   iamnzm@outlook.com|     0.0|   0.0|2019-09-19 08:45|
#   iamnzm@outlook.com|     0.0|   0.0|2019-09-19 08:50|
#   iamnzm@outlook.com|    11.0| 900.0|2019-09-19 08:55|
#   iamnzm@outlook.com|     2.0|  25.0|2019-09-19 09:00|
#   iamnzm@outlook.com|    37.0| 336.0|2019-09-19 09:05|
# deepshukla292@gma...|     0.0|  55.0|2019-09-19 09:05|
#   iamnzm@outlook.com|     0.0| 136.0|2019-09-19 09:10|
# deepshukla292@gma...|     6.0|1112.0|2019-09-19 09:10|
#   iamnzm@outlook.com|     0.0|  84.0|2019-09-19 09:15|
# deepshukla292@gma...|     0.0| 357.0|2019-09-19 09:15|
# markfernandes66@g...|    20.0| 670.0|2019-09-19 09:15|
# markfernandes66@g...|    17.0|   0.0|2019-09-19 09:10|
# markfernandes66@g...|    29.0|1895.0|2019-09-19 09:20|
#   iamnzm@outlook.com|     0.0|  29.0|2019-09-19 09:20|
# deepshukla292@gma...|    35.0|3022.0|2019-09-19 09:20|
# markfernandes66@g...|     2.0| 238.0|2019-09-19 09:25|
#   iamnzm@outlook.com|     0.0|   0.0|2019-09-19 09:25|
# deepshukla292@gma...|    20.0|1330.0|2019-09-19 09:25|
# markfernandes66@g...|     5.0|  39.0|2019-09-19 09:30|
# +--------------------+--------+------+----------------+
# only showing top 20 rows
#
# </div>

# %%
# %sql
CREATE table cpu_idle_working1 AS (SELECT `user_name`,bigint(to_timestamp(`time`)) AS datetime_bigint,
case
when (`keyboard`>0 OR `mouse`>0) then 'working'
else 'idle'
end AS Work_Status
FROM `CpuLogData_All1`)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
df=spark.sql("""SELECT * FROM cpu_idle_working1""")
df.write.csv('dbfs:/mnt/CPU_Logs/cpu_idle_working1')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * FROM cpu_idle_working1 limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_name</th><th>datetime_bigint</th><th>Work_Status</th></tr></thead><tbody><tr><td>iamnzm@outlook.com</td><td>1568882400</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568882700</td><td>idle</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883000</td><td>idle</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883300</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883600</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883900</td><td>working</td></tr><tr><td>deepshukla292@gmail.com</td><td>1568883900</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568884200</td><td>working</td></tr><tr><td>deepshukla292@gmail.com</td><td>1568884200</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568884500</td><td>working</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM cpu_idle_working1 where work_status='idle' limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_name</th><th>datetime_bigint</th><th>Work_Status</th></tr></thead><tbody><tr><td>iamnzm@outlook.com</td><td>1568882700</td><td>idle</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883000</td><td>idle</td></tr><tr><td>iamnzm@outlook.com</td><td>1568885100</td><td>idle</td></tr><tr><td>iamnzm@outlook.com</td><td>1568885400</td><td>idle</td></tr><tr><td>markfernandes66@gmail.com</td><td>1568885700</td><td>idle</td></tr><tr><td>markfernandes66@gmail.com</td><td>1568886000</td><td>idle</td></tr><tr><td>markfernandes66@gmail.com</td><td>1568886300</td><td>idle</td></tr><tr><td>iamnzm@outlook.com</td><td>1568887200</td><td>idle</td></tr><tr><td>markfernandes66@gmail.com</td><td>1568888100</td><td>idle</td></tr><tr><td>damodharn21@gmail.com</td><td>1568890200</td><td>idle</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM cpu_idle_working1 where work_status='working' limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_name</th><th>datetime_bigint</th><th>Work_Status</th></tr></thead><tbody><tr><td>iamnzm@outlook.com</td><td>1568882400</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883300</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883600</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568883900</td><td>working</td></tr><tr><td>deepshukla292@gmail.com</td><td>1568883900</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568884200</td><td>working</td></tr><tr><td>deepshukla292@gmail.com</td><td>1568884200</td><td>working</td></tr><tr><td>iamnzm@outlook.com</td><td>1568884500</td><td>working</td></tr><tr><td>deepshukla292@gmail.com</td><td>1568884500</td><td>working</td></tr><tr><td>markfernandes66@gmail.com</td><td>1568884500</td><td>working</td></tr></tbody></table></div>

# %%
# %sql
ANALYZE TABLE cpu_idle_working1 COMPUTE STATISTICS;
DESC EXTENDED cpu_idle_working1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>user_name</td><td>string</td><td></td></tr><tr><td>datetime_bigint</td><td>bigint</td><td></td></tr><tr><td>Work_Status</td><td>string</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Name</td><td>default.cpu_idle_working1</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/cpu_idle_working1</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM cpu_idle_working1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>4122</td></tr></tbody></table></div>

# %%
# %sql
CREATE table user_idle_time1 AS (SELECT user_name,datetime_bigint,Work_Status,
datetime_bigint - lag(datetime_bigint) over (order by datetime_bigint) AS time_idle_no_work
FROM cpu_idle_working1 where work_status='idle')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM user_idle_time1 limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_name</th><th>datetime_bigint</th><th>Work_Status</th><th>time_idle_no_work</th></tr></thead><tbody><tr><td>rahilstar11@gmail.com</td><td>1568638500</td><td>idle</td><td>null</td></tr><tr><td>iamnzm@outlook.com</td><td>1568640000</td><td>idle</td><td>1500</td></tr><tr><td>rahilstar11@gmail.com</td><td>1568640300</td><td>idle</td><td>300</td></tr><tr><td>iamnzm@outlook.com</td><td>1568640300</td><td>idle</td><td>0</td></tr><tr><td>sharlawar77@gmail.com</td><td>1568640300</td><td>idle</td><td>0</td></tr><tr><td>rahilstar11@gmail.com</td><td>1568640600</td><td>idle</td><td>300</td></tr><tr><td>iamnzm@outlook.com</td><td>1568640600</td><td>idle</td><td>0</td></tr><tr><td>deepshukla292@gmail.com</td><td>1568640600</td><td>idle</td><td>0</td></tr><tr><td>sharlawar77@gmail.com</td><td>1568640600</td><td>idle</td><td>0</td></tr><tr><td>rahilstar11@gmail.com</td><td>1568640900</td><td>idle</td><td>300</td></tr></tbody></table></div>

# %%
# %sql
-- User average idle hours with user_name
SELECT from_unixtime(round((sum(time_idle_no_work)/6),2),'HH:mm') AS user_Avg_idle_hours,user_name FROM user_idle_time1 group by user_name order by user_Avg_idle_hours desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_Avg_idle_hours</th><th>user_name</th></tr></thead><tbody><tr><td>05:57</td><td>sharlawar77@gmail.com</td></tr><tr><td>05:45</td><td>iamnzm@outlook.com</td></tr><tr><td>03:32</td><td>deepshukla292@gmail.com</td></tr><tr><td>01:47</td><td>rahilstar11@gmail.com</td></tr><tr><td>01:30</td><td>salinabodale73@gmail.com</td></tr><tr><td>01:03</td><td>bhagyashrichalke21@gmail.com</td></tr><tr><td>00:49</td><td>damodharn21@gmail.com</td></tr><tr><td>00:37</td><td>markfernandes66@gmail.com</td></tr></tbody></table></div>

# %%
# Writing above table as csv file to Azure blob storage
df=spark.sql("""SELECT from_unixtime(round(sum(time_idle_no_work)/(6),3),'HH:mm') AS user_Avg_idle_hours,user_name FROM user_idle_time1 group by user_name order by user_Avg_idle_hours desc """)
df.show()
df.write.option.csv("header",true,'dbfs:/mnt/CPU_Logs/user_Avg_idle_hours')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+--------------------+
# user_Avg_idle_hours|           user_name|
# +-------------------+--------------------+
#               05:57|sharlawar77@gmail...|
#               05:45|  iamnzm@outlook.com|
#               03:32|deepshukla292@gma...|
#               01:47|rahilstar11@gmail...|
#               01:30|salinabodale73@gm...|
#               01:03|bhagyashrichalke2...|
#               00:49|damodharn21@gmail...|
#               00:37|markfernandes66@g...|
# +-------------------+--------------------+
#
# </div>

# %%
# %sql
CREATE table user_working_time1 AS (SELECT user_name,datetime_bigint,Work_Status,
datetime_bigint - lag(datetime_bigint) over (order by datetime_bigint) AS time_user_working
FROM cpu_idle_working1 where work_status='working')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM user_working_time1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>3167</td></tr></tbody></table></div>

# %%
# %sql
SELECT from_unixtime(round(sum(time_user_working)/6,3),'HH:mm') AS user_Avg_work_hours,user_name FROM user_working_time1 group by user_name order by user_Avg_work_hours desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_Avg_work_hours</th><th>user_name</th></tr></thead><tbody><tr><td>06:56</td><td>iamnzm@outlook.com</td></tr><tr><td>03:49</td><td>sharlawar77@gmail.com</td></tr><tr><td>03:38</td><td>deepshukla292@gmail.com</td></tr><tr><td>03:29</td><td>salinabodale73@gmail.com</td></tr><tr><td>01:41</td><td>rahilstar11@gmail.com</td></tr><tr><td>00:35</td><td>markfernandes66@gmail.com</td></tr><tr><td>00:33</td><td>damodharn21@gmail.com</td></tr><tr><td>00:23</td><td>bhagyashrichalke21@gmail.com</td></tr></tbody></table></div>

# %%
df = spark.sql("""
            SELECT from_unixtime(round(sum(time_user_working)/6,3),'HH:mm') AS user_Avg_work_hours,user_name FROM user_working_time1 group by user_name order by user_Avg_work_hours desc
            """)
df.show()
df.write.option.csv("header",true,'dbfs:/mnt/CPU_Logs/user_Avg_idle_hours')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+--------------------+
# user_Avg_work_hours|           user_name|
# +-------------------+--------------------+
#               06:56|  iamnzm@outlook.com|
#               03:49|sharlawar77@gmail...|
#               03:38|deepshukla292@gma...|
#               03:29|salinabodale73@gm...|
#               01:41|rahilstar11@gmail...|
#               00:35|markfernandes66@g...|
#               00:33|damodharn21@gmail...|
#               00:23|bhagyashrichalke2...|
# +-------------------+--------------------+
#
# </div>
