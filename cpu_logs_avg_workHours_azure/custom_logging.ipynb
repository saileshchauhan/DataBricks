# %% [markdown]
# ##### Author: Sailesh Chauhan
# ##### Date: 28/07/2021
# ##### Title: Custom logging configuration. Then, use the same logging configuration in other NoteBooks.

# %% [markdown]
# Program for creating log file.Then, using it for logging notebook execution statements.
# * configuration level -> DEBUG.
# * file path -> '/tmp/'
# * Use commented code to get separate log file with different timestamp.

# %%
import logging
import datetime
import time


# Uncomment below two lines to get separate log file for different date.
file_date = datetime.datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d-%H-%M-%S')
p_filename = "custom_log"+file_date+".log"

p_dir = '/tmp/'
#p_filename = 'custom_log.log'
p_logfile = p_dir + p_filename
print(p_logfile)


logger = logging.getLogger('custom_log')
logger.setLevel(logging.DEBUG)

f_handler = logging.FileHandler(p_logfile, mode = 'a')


c_handler = logging.StreamHandler()
c_handler.setLevel(logging.DEBUG)


f_format = logging.Formatter("%(asctime)s - %(name)s - %(levelname)s - %(message)s")

f_handler.setFormatter(f_format)
c_handler.setFormatter(f_format)

if (logger.hasHandlers()):
  logger.handlers.clear()
  
logger.addHandler(f_handler)
logger.addHandler(c_handler)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/tmp/custom_log2021-07-28-10-03-22.log
# </div>

# %%
# %fs
ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/dbfs/</td><td>dbfs/</td><td>0</td></tr><tr><td>dbfs:/mnt/</td><td>mnt/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
