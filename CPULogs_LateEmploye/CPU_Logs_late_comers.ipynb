# %%
# %run ./custom_logging

# %% [markdown]
# ### Author: Sailesh Chauhan
# ### Date: 26/07/2021
# ### Title: Find late ariving employe average late coming time from provided CPU Logs data in csv files.

# %%
# %fs
ls dbfs:/FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_16.csv</td><td>CpuLogData2019_09_16.csv</td><td>177697</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_17.csv</td><td>CpuLogData2019_09_17.csv</td><td>299062</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_18.csv</td><td>CpuLogData2019_09_18.csv</td><td>286264</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_19.csv</td><td>CpuLogData2019_09_19.csv</td><td>346015</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_20.csv</td><td>CpuLogData2019_09_20.csv</td><td>136532</td></tr><tr><td>dbfs:/FileStore/tables/CpuLogData2019_09_21.csv</td><td>CpuLogData2019_09_21.csv</td><td>291933</td></tr><tr><td>dbfs:/FileStore/tables/LMS_DB.zip</td><td>LMS_DB.zip</td><td>636912</td></tr></tbody></table></div>

# %% [markdown]
# ##### Mounting AzureStorage account container in databricks filestorage system

# %%
AZURE_KEY=spark.conf.get('spark.azure_key')
dbutils.fs.mount(
  source = "wasbs://cpu-logs-latecomer@cpulogs.blob.core.windows.net",
  mount_point = "/mnt/CPU_Logs_Late_comers",
  extra_configs ={"fs.azure.account.key.cpulogs.blob.core.windows.net":AZURE_KEY})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: True</div>

# %% [markdown]
# #### Loading all csv files for each cpu log dates from 2019-09-16 to 2019-09-21 into dataframe df. Then selecting required use columns DateTime and user_name.

# %%
try:
  file_location=['dbfs:/FileStore/tables/CpuLogData2019_09_21.csv','dbfs:/FileStore/tables/CpuLogData2019_09_20.csv','dbfs:/FileStore/tables/CpuLogData2019_09_19.csv','dbfs:/FileStore/tables/CpuLogData2019_09_18.csv','dbfs:/FileStore/tables/CpuLogData2019_09_17.csv','dbfs:/FileStore/tables/CpuLogData2019_09_16.csv']

  file_type='csv'

  infer_schema = "true"
  first_row_is_header = "true"
  delimiter = ","

  df = spark.read.format(file_type) \
    .option("inferSchema", infer_schema) \
    .option("header", first_row_is_header) \
    .option("sep", delimiter) \
    .load(file_location)

  df_CPU=df.select("DateTime","user_name")
  rows=df_CPU.count()
  df_CPU.describe()
  rows
  logger.info("All csv files loaded in data frame df_CPU")
except Exception as ex:
  logger.error("files not loaded in data frame df_CPU : "+str(ex))
  
logging.shutdown()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-07-28 10:16:19,331 - custom_log - INFO - All csv files loaded in data frame df_CPU
# INFO:custom_log:All csv files loaded in data frame df_CPU
# </div>

# %% [markdown]
# ##### Adding date column to df_CPU dataframe from DateTime attribute of df_CPU

# %%
from pyspark.sql.functions import date_format
try:
  df_CPU = df_CPU.withColumn('date',date_format('DateTime', 'yyyy-MM-dd'))
  df_CPU.printSchema()
  logger.debug("Column typecasted to time format")
except Exception as ex:
  logger.error("Failed column type casting :"+str(ex))

logging.shutdown()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- DateTime: string (nullable = true)
# -- user_name: string (nullable = true)
# -- date: string (nullable = true)
#
# 2021-07-28 10:17:37,178 - custom_log - DEBUG - Column typecasted to time format
# DEBUG:custom_log:Column typecasted to time format
# </div>

# %% [markdown]
# ##### Creating temparory view of dataframe df_CPU as cpu_all_dates

# %%
try:
  temp_view="cpu_all_dates"
  df_CPU.createOrReplaceTempView(temp_view)
  logger.debug("Created temprorary view cpu_all_dates")
except Exception as ex:
  logger.error("failed to create view cpu_all_dates")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-07-28 10:19:31,901 - custom_log - DEBUG - Created temprorary view cpu_all_dates
# DEBUG:custom_log:Created temprorary view cpu_all_dates
# </div>

# %% [markdown]
# ##### Type casting DateTime and date attributes to timestamp

# %%
try:
  df=spark.sql("select to_timestamp(DateTime) as Datetime,user_name,to_timestamp(date) as date from cpu_all_dates")
  logger.debug("Type casting date to timestamp from string")
except Exception as ex:
  logger.error("date coversion failed "+str(ex))

logging.shutdown()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-07-28 10:31:51,066 - custom_log - DEBUG - Type casting date to timestamp from string
# DEBUG:custom_log:Type casting date to timestamp from string
# </div>

# %%
try:
  display(df.take(5))
  logger.debug("display top 5")
except Exception as ex:
  logger.error("Failed to display "+str(ex))
logging.shutdown()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Datetime</th><th>user_name</th><th>date</th></tr></thead><tbody><tr><td>2019-09-19T08:40:02.000+0000</td><td>iamnzm@outlook.com</td><td>2019-09-19T00:00:00.000+0000</td></tr><tr><td>2019-09-19T08:45:02.000+0000</td><td>iamnzm@outlook.com</td><td>2019-09-19T00:00:00.000+0000</td></tr><tr><td>2019-09-19T08:50:01.000+0000</td><td>iamnzm@outlook.com</td><td>2019-09-19T00:00:00.000+0000</td></tr><tr><td>2019-09-19T08:55:01.000+0000</td><td>iamnzm@outlook.com</td><td>2019-09-19T00:00:00.000+0000</td></tr><tr><td>2019-09-19T09:00:01.000+0000</td><td>iamnzm@outlook.com</td><td>2019-09-19T00:00:00.000+0000</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-07-28 10:36:35,439 - custom_log - DEBUG - display top 5
# DEBUG:custom_log:display top 5
# </div>

# %%
try:
  df.createOrReplaceTempView(temp_view)
  logger.debug("cpu_all_dates view created success")
except Exception as ex:
  logger.error('cpu_all_dates view failed '+str(ex))
  
logging.shutdown()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-07-28 10:37:15,010 - custom_log - DEBUG - cpu_all_dates view created success
# DEBUG:custom_log:cpu_all_dates view created success
# </div>

# %% [markdown]
# ## SQL

# %%
# %sql
select count(*) from cpu_all_dates
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>4122</td></tr></tbody></table></div>

# %% [markdown]
# ##### Creating temparory view cpu_all_loginTime

# %%
# %sql
create temp view cpu_all_loginTime as select min(datetime) as log_In_Time,user_name,date from cpu_all_dates group by date,user_name order by log_In_Time
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from cpu_all_loginTime
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>log_In_Time</th><th>user_name</th><th>date</th></tr></thead><tbody><tr><td>2019-09-16T12:55:01.000+0000</td><td>bhagyashrichalke21@gmail.com</td><td>2019-09-16T00:00:00.000+0000</td></tr><tr><td>2019-09-16T12:55:02.000+0000</td><td>salinabodale73@gmail.com</td><td>2019-09-16T00:00:00.000+0000</td></tr><tr><td>2019-09-16T12:55:03.000+0000</td><td>rahilstar11@gmail.com</td><td>2019-09-16T00:00:00.000+0000</td></tr><tr><td>2019-09-16T13:00:01.000+0000</td><td>iamnzm@outlook.com</td><td>2019-09-16T00:00:00.000+0000</td></tr><tr><td>2019-09-16T13:00:01.000+0000</td><td>deepshukla292@gmail.com</td><td>2019-09-16T00:00:00.000+0000</td></tr><tr><td>2019-09-16T13:00:04.000+0000</td><td>sharlawar77@gmail.com</td><td>2019-09-16T00:00:00.000+0000</td></tr><tr><td>2019-09-17T08:25:01.000+0000</td><td>iamnzm@outlook.com</td><td>2019-09-17T00:00:00.000+0000</td></tr><tr><td>2019-09-17T09:30:01.000+0000</td><td>deepshukla292@gmail.com</td><td>2019-09-17T00:00:00.000+0000</td></tr><tr><td>2019-09-17T09:40:01.000+0000</td><td>rahilstar11@gmail.com</td><td>2019-09-17T00:00:00.000+0000</td></tr><tr><td>2019-09-17T10:10:01.000+0000</td><td>salinabodale73@gmail.com</td><td>2019-09-17T00:00:00.000+0000</td></tr><tr><td
gmail.com</td><td>2019-09-19T00:00:00.000+0000</td></tr><tr><td>6901</td><td>damodharn21@gmail.com</td><td>2019-09-19T00:00:00.000+0000</td></tr><tr><td>0</td><td>sharlawar77@gmail.com</td><td>2019-09-20T00:00:00.000+0000</td></tr><tr><td>3300</td><td>iamnzm@outlook.com</td><td>2019-09-20T00:00:00.000+0000</td></tr><tr><td>4500</td><td>markfernandes66@gmail.com</td><td>2019-09-20T00:00:00.000+0000</td></tr><tr><td>4501</td><td>rahilstar11@gmail.com</td><td>2019-09-20T00:00:00.000+0000</td></tr><tr><td>4800</td><td>bhagyashrichalke21@gmail.com</td><td>2019-09-20T00:00:00.000+0000</td></tr><tr><td>4800</td><td>salinabodale73@gmail.com</td><td>2019-09-20T00:00:00.000+0000</td></tr><tr><td>5101</td><td>damodharn21@gmail.com</td><td>2019-09-20T00:00:00.000+0000</td></tr><tr><td>0</td><td>deepshukla292@gmail.com</td><td>2019-09-21T00:00:00.000+0000</td></tr><tr><td>7800</td><td>rahilstar11@gmail.com</td><td>2019-09-21T00:00:00.000+0000</td></tr><tr><td>7800</td><td>salinabodale73@gmail.com</td><td>2019-09-21T00:00:00.000+0000</td></tr><tr><td>7800</td><td>markfernandes66@gmail.com</td><td>2019-09-21T00:00:00.000+0000</td></tr><tr><td>7801</td><td>bhagyashrichalke21@gmail.com</td><td>2019-09-21T00:00:00.000+0000</td></tr><tr><td>8100</td><td>iamnzm@outlook.com</td><td>2019-09-21T00:00:00.000+0000</td></tr><tr><td>8100</td><td>sharlawar77@gmail.com</td><td>2019-09-21T00:00:00.000+0000</td></tr><tr><td>9002</td><td>damodharn21@ ...

# %% [markdown]
# #### Result table to find number of times employees logged in late and average late arrival of each employee

# %%
# %sql
select from_unixtime(round(sum(delayedby)/6,2),'HH:mm') as Avg_late_hrs_min,user_name,count(user_name) as number_of_times_late from cpu_all_delayedby_latecount where delayedby!=0  group by user_name order by Avg_late_hrs_min desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Avg_late_hrs_min</th><th>user_name</th><th>number_of_times_late</th></tr></thead><tbody><tr><td>01:25</td><td>salinabodale73@gmail.com</td><td>6</td></tr><tr><td>01:25</td><td>bhagyashrichalke21@gmail.com</td><td>5</td></tr><tr><td>01:22</td><td>rahilstar11@gmail.com</td><td>6</td></tr><tr><td>01:08</td><td>markfernandes66@gmail.com</td><td>5</td></tr><tr><td>01:06</td><td>sharlawar77@gmail.com</td><td>5</td></tr><tr><td>00:58</td><td>damodharn21@gmail.com</td><td>3</td></tr><tr><td>00:32</td><td>iamnzm@outlook.com</td><td>3</td></tr><tr><td>00:21</td><td>deepshukla292@gmail.com</td><td>4</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/tmp/custom_log.log
# </div>

# %% [markdown]
# ##### Writing result in csv file format to mounted Azure conatiner storage

# %%
try:
  df = spark.sql("""
            select from_unixtime(round(sum(delayedby)/6,2),'HH:mm') as Avg_late_hrs_min,user_name,count(user_name) as number_of_times_late from cpu_all_delayedby_latecount where delayedby!=0  group by user_name order by Avg_late_hrs_min desc""")
  df.write.option("header",'true').csv('/mnt/CPU_Logs_Late_comers/Employe_Late')
  logger.debug('file written succesfully')
except Exception as ex:
  logger.error('file writing unsuccesful '+str(ex))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-07-28 10:41:50,264 - custom_log - ERROR -
# ERROR:custom_log:
# </div>
